# %%
import numpy as np
import pandas as pd
import gmplot
import geopandas as gpd
import geopy
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
import matplotlib.pyplot as plt
import plotly_express as px
from tqdm.notebook import tqdm

# %%
#data loading
df=pd.read_csv('/Users/anboguo/Desktop/Cap/Final/data_30sec.csv')
df=df.drop(columns='Unnamed: 0')
df['geom'] = df['latitude'].map(str) + ',' + df['longitude'].map(str)
df.head()
# Out:
#              timestamp   device beacon_type  major    minor  \
# 0  2021-09-14 14:22:30  device1     ibeacon    1.0      0.0
# 1  2021-09-14 14:23:00  device1     ibeacon    1.0      0.0
# 2  2021-09-14 14:23:30  device1     ibeacon    1.0      0.0
# 3  2021-09-14 14:23:30  device1     ibeacon    0.0  18358.0
# 4  2021-09-14 14:24:00  device1     ibeacon    1.0      0.0
#
#                                    uuid eddystoneUidData  rssi  tx_power  \
# 0  2686f39c-bada-4658-854a-a62e7e5e8b8d              NaN   -94       -47
# 1  2686f39c-bada-4658-854a-a62e7e5e8b8d              NaN   -92       -47
# 2  2686f39c-bada-4658-854a-a62e7e5e8b8d              NaN   -94       -47
# 3  74278bda-b644-4520-8f0c-720eaf059935              NaN   -90       -59
# 4  2686f39c-bada-4658-854a-a62e7e5e8b8d              NaN   -87       -47
#
#     distance  ...  CDEligibil                              NTAName  NTA2020  \
# 0  50.990363  ...         NaN  Downtown Brooklyn-DUMBO-Boerum Hill   BK0202
# ...

# %%
#reverse geocoding
locator = Nominatim(user_agent='myGeocoder', timeout=10)
rgeocode = RateLimiter(locator.reverse, min_delay_seconds=0.000001)
tqdm.pandas()
df['address'] = df['geom'].progress_apply(rgeocode)
df.head()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/tqdm/std.py:658: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# ...
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('40.690917799999994,-73.98679796',), **{}).
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py", line 360, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/opt/anaconda3/lib/python3.7/site-packages/geopy/adapters.py", line 373, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/opt/anaconda3/lib/python3.7/site-packages/geopy/adapters.py", line 404, in _request
#     text=resp.text,
# geopy.adapters.AdapterHTTPError: Non-successful status code 403
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df.columns
# Out:
# Index(['timestamp', 'device', 'beacon_type', 'major', 'minor', 'uuid',
#        'eddystoneUidData', 'rssi', 'tx_power', 'distance', 'latitude',
#        'longitude', 'speed(m/s)', 'manufacturer', 'last_seen', 'coordinates',
#        'index_right', 'level_0', 'level_1', 'OBJECTID', 'CTLabel', 'BoroCode',
#        'BoroName', 'CT2020', 'BoroCT2020', 'CDEligibil', 'NTAName', 'NTA2020',
#        'CDTA2020', 'CDTANAME', 'GEOID', 'Shape__Area', 'Shape__Length',
#        'census_id', 'geom'],
#       dtype='object')

# %%
GPS1=pd.read_csv('/Users/anboguo/Desktop/Cap/Report 3/device1 - 20210908-211023.txt',sep=',')
GPS3=pd.read_csv('/Users/anboguo/Desktop/Cap/Report 3/device3 - 20210924-211015.txt',sep=',')
GPS4=pd.read_csv('/Users/anboguo/Desktop/Cap/Report 3/device4 - 20210928-211106.txt',sep=',')
frames=[GPS1,GPS3,GPS4]
GPS=pd.concat(frames,ignore_index=True)
GPS.head()
# Out:
#   type            date time   latitude  longitude  accuracy(m)  altitude(m)  \
# 0    T  2021-09-08 22:47:52  40.692930 -73.986386           18       26.942
# 1    T  2021-09-08 22:47:54  40.692903 -73.986363           17       25.957
# 2    T  2021-09-08 22:47:55  40.692900 -73.986359           17       25.997
# 3    T  2021-09-08 22:47:56  40.692875 -73.986331           17       25.700
# 4    T  2021-09-08 22:47:57  40.692876 -73.986320           16       26.024
#
#    geoid_height(m)  speed(m/s)  bearing(deg)  sat_used  sat_inview  name  desc
# 0              NaN        0.00           NaN      21.0          26   NaN   NaN
# 1              NaN        0.44         338.0      16.0          26   NaN   NaN
# 2              NaN        0.65         331.0      15.0          26   NaN   NaN
# 3              NaN        0.48         352.0      17.0          26   NaN   NaN
# 4              NaN        0.81          18.0      16.0          26   NaN   NaN

# %%
latitude_list = list(df['latitude'])
longitude_list = list(df['longitude'])
geom_list = list(df['geom'])
latitude_GPS = list(GPS['latitude'])
longitude_GPS = list(GPS['longitude'])

# %%
apikey = 'AIzaSyDvtgCGnm7-ZEenxQBuRlGiRfDVe1_k98k'
gmap = gmplot.GoogleMapPlotter(40.693273, -73.989462, 13, apikey = apikey)

gmap.scatter(latitude_GPS, longitude_GPS, color = 'grey', size = 10, marker = False)
gmap.scatter(latitude_list, longitude_list, color = 'orangered', size = 20, marker = True, title = geom_list)


#export to your path
gmap.draw('/Users/anboguo/Desktop/beacon with info.html')

# %%
#merge overlapping points
GPSround=GPS[['latitude','longitude']]
GPSround['latitude']=round(GPSround['latitude'],4)
GPSround['longitude']=round(GPSround['longitude'],4)
GPSround=GPSround.drop_duplicates()
GPSround.head()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#     latitude  longitude
# 0    40.6929   -73.9864
# 3    40.6929   -73.9863
# 12   40.6929   -73.9862
# 37   40.6930   -73.9862
# ...

# %%
latitude_list = list(GPSround['latitude'])
longitude_list = list(GPSround['longitude'])
apikey = 'AIzaSyDvtgCGnm7-ZEenxQBuRlGiRfDVe1_k98k'
gmap = gmplot.GoogleMapPlotter(40.693273, -73.989462, 13, apikey = apikey)
gmap.scatter(latitude_list, longitude_list, color = 'grey', size = 10, marker = False)

#export to your path
gmap.draw('/Users/anboguo/Desktop/test.html')

# %%
dfround=df[['uuid','major','minor','latitude','longitude','geom']]
dfround['latitude']=round(dfround['latitude'],4)
dfround['longitude']=round(dfround['longitude'],4)
dfround['geom']='('+dfround['geom']+')'
dfround.head()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
dfmerge=dfround.groupby(['uuid','major','minor','latitude','longitude']).count().reset_index()
geoms=[]
for i in range(len(dfmerge)):
    geoms.append(' '.join(dfround[(dfround['uuid']==dfmerge['uuid'][i]) & (dfround['major']==dfmerge['major'][i]) & (dfround['minor']==dfmerge['minor'][i]) & (dfround['latitude']==dfmerge['latitude'][i]) & (dfround['longitude']==dfmerge['longitude'][i])]['geom']))
dfmerge['geoms']=geoms
info=[]
for j in range(len(dfmerge)):
    info.append('uuid: '+' '+dfmerge['uuid'][j]+' '+'major: '+str(dfmerge['major'][j])+' '+'minor: '+str(dfmerge['minor'][j])+' '+'location: '+' '+dfmerge['geoms'][j])
dfmerge['info']=info
dfmerge.head()
# Out:
#                                    uuid    major    minor  latitude  \
# 0  00009999-0000-1000-8000-00177a000002  43690.0  48059.0   40.6900
# 1  00009999-0000-1000-8000-00177a000002  43690.0  48059.0   40.6900
# 2  00009999-0000-1000-8000-00177a000002  43690.0  48059.0   40.6901
# 3  00009999-0000-1000-8000-00177a000002  43690.0  48059.0   40.6901
# 4  00009999-0000-1000-8000-00177a000002  43690.0  48059.0   40.6904
#
#    longitude  geom                                              geoms  \
# 0   -73.9837     2  (40.68998156,-73.98371807) (40.68998871,-73.98...
# 1   -73.9836     1                   (40.69000405,-73.98355550000001)
# 2   -73.9839     1                         (40.69011941,-73.98385313)
# 3   -73.9837     1                         (40.69006569,-73.98372905)
# 4   -73.9848     1                         (40.69040991,-73.98484638)
#
#                                                 info
# 0  uuid:  00009999-0000-1000-8000-00177a000002 ma...
# ...

# %%
dfr=dfmerge[['latitude','longitude','info']]
dfr=dfr.drop_duplicates()
dfr.head()
# Out:
#    latitude  longitude                                               info
# 0   40.6900   -73.9837  uuid:  00009999-0000-1000-8000-00177a000002 ma...
# 1   40.6900   -73.9836  uuid:  00009999-0000-1000-8000-00177a000002 ma...
# 2   40.6901   -73.9839  uuid:  00009999-0000-1000-8000-00177a000002 ma...
# 3   40.6901   -73.9837  uuid:  00009999-0000-1000-8000-00177a000002 ma...
# 4   40.6904   -73.9848  uuid:  00009999-0000-1000-8000-00177a000002 ma...

# %%
#add street 
data=pd.read_csv('/Users/anboguo/Desktop/Cap/Final/final_merged_data.csv')
data=data[['latitude','longitude','display_name']]
data['latitude']=round(data['latitude'],4)
data['longitude']=round(data['longitude'],4)
data.head()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (6,38,64,68,70,71,72,74) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    latitude  longitude                                       display_name
# 0   40.6909   -73.9868  400, Fulton Street, Downtown Brooklyn, Brookly...
# 1   40.6909   -73.9864  408, Fulton Street, Downtown Brooklyn, Brookly...
# 2   40.6908   -73.9861  McDonald's, Fulton Mall, Downtown Brooklyn, Br...
# 3   40.6908   -73.9860  McDonald's, Fulton Mall, Downtown Brooklyn, Br...
# 4   40.6907   -73.9857  Hoyt Street, Duffield Street, Downtown Brookly...

# %%
dfr=dfr.merge(data,left_on=['latitude','longitude'],right_on=['latitude','longitude'])
dfr.head()
# Out:
#    latitude  longitude                                               info  \
# 0   40.6900   -73.9837  uuid:  00009999-0000-1000-8000-00177a000002 ma...
# 1   40.6900   -73.9837  uuid:  00009999-0000-1000-8000-00177a000002 ma...
# 2   40.6900   -73.9836  uuid:  00009999-0000-1000-8000-00177a000002 ma...
# 3   40.6901   -73.9839  uuid:  00009999-0000-1000-8000-00177a000002 ma...
# 4   40.6901   -73.9839  uuid:  00009999-0000-1000-8000-00177a000002 ma...
#
#                                         display_name
# 0  Fulton Mall, Downtown Brooklyn, Brooklyn, King...
# 1  Fulton Mall, Downtown Brooklyn, Brooklyn, King...
# 2  Hook & Reel, 430, Albee Square, Downtown Brook...
# 3  Fulton Mall, Downtown Brooklyn, Brooklyn, King...
# 4  Fulton Mall, Downtown Brooklyn, Brooklyn, King...

# %%
dfr['info']=dfr['info']+' '+'address: '+dfr['display_name']
dfr['info']
# Out:
# 0        uuid:  00009999-0000-1000-8000-00177a000002 ma...
# 1        uuid:  00009999-0000-1000-8000-00177a000002 ma...
# 2        uuid:  00009999-0000-1000-8000-00177a000002 ma...
# 3        uuid:  00009999-0000-1000-8000-00177a000002 ma...
# 4        uuid:  00009999-0000-1000-8000-00177a000002 ma...
#                                ...
# 43740    uuid:  fdb3b09b-12e2-4442-be37-35a00a1d9a06 ma...
# 43741    uuid:  fe913213-b311-4a42-8c16-47faeac938db ma...
# 43742    uuid:  fe913213-b311-4a42-8c16-47faeac938db ma...
# 43743    uuid:  fe913213-b311-4a42-8c16-47faeac938db ma...
# 43744    uuid:  fe913213-b311-4a42-8c16-47faeac938db ma...
# Name: info, Length: 43745, dtype: object

# %%
latitude_list = list(dfr['latitude'])
longitude_list = list(dfr['longitude'])
info_list = list(dfr['info'])

apikey = 'AIzaSyDvtgCGnm7-ZEenxQBuRlGiRfDVe1_k98k'
gmap = gmplot.GoogleMapPlotter(40.693273, -73.989462, 13, apikey = apikey)
gmap.scatter(latitude_list, longitude_list, color = 'orangered', size = 20, marker = True, title = info_list)

#export to your path
gmap.draw('/Users/anboguo/Desktop/test2.html')

# %%
latitude_GPS = list(GPSround['latitude'])
longitude_GPS = list(GPSround['longitude'])
latitude_list = list(dfr['latitude'])
longitude_list = list(dfr['longitude'])
info_list = list(dfr['info'])
apikey = 'AIzaSyDvtgCGnm7-ZEenxQBuRlGiRfDVe1_k98k'
gmap = gmplot.GoogleMapPlotter(40.693273, -73.989462, 13, apikey = apikey)

gmap.scatter(latitude_GPS, longitude_GPS, color = 'grey', size = 10, marker = False)
gmap.scatter(latitude_list, longitude_list, color = 'orangered', size = 20, marker = True, title = info_list)


#export to your path
gmap.draw('/Users/anboguo/Desktop/beacons with info.html')
